# %%
import keras
import numpy as np
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Flatten, Dense, Dropout
from keras.callbacks import ModelCheckpoint

# Load data (RGB Images: 32 x 32)
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Scale
scale = 255
x_train = x_train.astype('float32') / scale
x_test = x_test.astype('float32') / scale

# One-hot encode the labels
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# Model
model = Sequential()
model.add(Flatten(input_shape = x_train.shape[1:]))
model.add(Dense(256, activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(128, activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation = 'softmax'))

model.summary()

print('Hello, start training!')

# Compile the model
model.compile(loss = 'categorical_crossentropy', 
              optimizer = 'rmsprop', metrics = ['accuracy'])

# Start training
hist = model.fit(x_train, y_train,
                batch_size = 32, epochs = 5,
                verbose = 2, shuffle = True)

# Calculate the Accuracy
score = model.evaluate(x_test, y_test, verbose = 0)
print('Accuarcy:', score[1])

model.save_weights('mlp_model.hdf5')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 3072)              0
#
#  dense_3 (Dense)             (None, 256)               786688
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 820,874
# Trainable params: 820,874
# Non-trainable params: 0
# _________________________________________________________________
# Hello, start training!
# Epoch 1/5
# 1563/1563 - 23s - loss: 2.0286 - accuracy: 0.2536 - 23s/epoch - 14ms/step
# Epoch 2/5
# 1563/1563 - 22s - loss: 1.8856 - accuracy: 0.3076 - 22s/epoch - 14ms/step
# Epoch 3/5
# 1563/1563 - 21s - loss: 1.8449 - accuracy: 0.3299 - 21s/epoch - 14ms/step
# Epoch 4/5
# 1563/1563 - 21s - loss: 1.8196 - accuracy: 0.3371 - 21s/epoch - 13ms/step
# Epoch 5/5
# 1563/1563 - 22s - loss: 1.8004 - accuracy: 0.3463 - 22s/epoch - 14ms/step
# Accuarcy: 0.37940001487731934
# Finished!!!
# Save Done
